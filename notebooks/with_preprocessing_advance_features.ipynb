# %% [markdown]
# ## Advanced Features
#
# ### 1. Token Features
# - **cwc_min**: This is the ratio of the number of common words to the length of the smaller question
# - **cwc_max**: This is the ratio of the number of common words to the length of the larger question
# - **csc_min**: This is the ratio of the number of common stop words to the smaller stop word count among the two questions
# - **csc_max**: This is the ratio of the number of common stop words to the larger stop word count among the two questions
# - **ctc_min**: This is the ratio of the number of common tokens to the smaller token count among the two questions
# - **ctc_max**: This is the ratio of the number of common tokens to the larger token count among the two questions
# - **last_word_eq**: 1 if the last word in the two questions is same, 0 otherwise
# - **first_word_eq**: 1 if the first word in the two questions is same, 0 otherwise
#
# ### 2. Length Based Features
# - **mean_len**: Mean of the length of the two questions (number of words)
# - **abs_len_diff**: Absolute difference between the length of the two questions (number of words)
# - **longest_substr_ratio**: Ratio of the length of the longest substring among the two questions to the length of the smaller question
#
# ### 3. Fuzzy Features
# - **fuzz_ratio**: fuzz_ratio score from fuzzywuzzy
# - **fuzz_partial_ratio**: fuzz_partial_ratio from fuzzywuzzy
# - **token_sort_ratio**: token_sort_ratio from fuzzywuzzy
# - **token_set_ratio**: token_set_ratio from fuzzywuzzy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import re
from bs4 import BeautifulSoup

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("/content/train.csv")

# %%
df.shape
# Out:
# (404290, 6)

# %%
new_df = df.sample(20000,random_state=2)

# %%
new_df.shape
# Out:
# (20000, 6)

# %%
new_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
def preprocess(q):

    q = str(q).lower().strip()

    # Replace certain special characters with their string equivalents
    q = q.replace('%', ' percent')
    q = q.replace('$', ' dollar ')
    q = q.replace('₹', ' rupee ')
    q = q.replace('€', ' euro ')
    q = q.replace('@', ' at ')

    # The pattern '[math]' appears around 900 times in the whole dataset.
    q = q.replace('[math]', '')

    # Replacing some numbers with string equivalents (not perfect, can be done better to account for more cases)
    q = q.replace(',000,000,000 ', 'b ')
    q = q.replace(',000,000 ', 'm ')
    q = q.replace(',000 ', 'k ')
    q = re.sub(r'([0-9]+)000000000', r'\1b', q)
    q = re.sub(r'([0-9]+)000000', r'\1m', q)
    q = re.sub(r'([0-9]+)000', r'\1k', q)

    # Decontracting words
    # https://en.wikipedia.org/wiki/Wikipedia%3aList_of_English_contractions
    # https://stackoverflow.com/a/19794953
    contractions = {
    "ain't": "am not",
    "aren't": "are not",
    "can't": "can not",
    "can't've": "can not have",
    "'cause": "because",
    "could've": "could have",
    "couldn't": "could not",
    "couldn't've": "could not have",
    "didn't": "did not",
    "doesn't": "does not",
    "don't": "do not",
    "hadn't": "had not",
    "hadn't've": "had not have",
    "hasn't": "has not",
    "haven't": "have not",
    "he'd": "he would",
    "he'd've": "he would have",
    "he'll": "he will",
    "he'll've": "he will have",
    "he's": "he is",
    "how'd": "how did",
    "how'd'y": "how do you",
    "how'll": "how will",
    "how's": "how is",
    "i'd": "i would",
    "i'd've": "i would have",
    "i'll": "i will",
    "i'll've": "i will have",
    "i'm": "i am",
    "i've": "i have",
    "isn't": "is not",
    "it'd": "it would",
    "it'd've": "it would have",
    "it'll": "it will",
    "it'll've": "it will have",
    "it's": "it is",
    "let's": "let us",
    "ma'am": "madam",
    "mayn't": "may not",
    "might've": "might have",
    "mightn't": "might not",
    "mightn't've": "might not have",
    "must've": "must have",
    "mustn't": "must not",
    "mustn't've": "must not have",
    "needn't": "need not",
    "needn't've": "need not have",
    "o'clock": "of the clock",
    "oughtn't": "ought not",
    "oughtn't've": "ought not have",
    "shan't": "shall not",
    "sha'n't": "shall not",
    "shan't've": "shall not have",
    "she'd": "she would",
    "she'd've": "she would have",
    "she'll": "she will",
    "she'll've": "she will have",
    "she's": "she is",
    "should've": "should have",
    "shouldn't": "should not",
    "shouldn't've": "should not have",
    "so've": "so have",
    "so's": "so as",
    "that'd": "that would",
    "that'd've": "that would have",
    "that's": "that is",
    "there'd": "there would",
    "there'd've": "there would have",
    "there's": "there is",
    "they'd": "they would",
    "they'd've": "they would have",
    "they'll": "they will",
    "they'll've": "they will have",
    "they're": "they are",
    "they've": "they have",
    "to've": "to have",
    "wasn't": "was not",
    "we'd": "we would",
    "we'd've": "we would have",
    "we'll": "we will",
    "we'll've": "we will have",
    "we're": "we are",
    "we've": "we have",
    "weren't": "were not",
    "what'll": "what will",
    "what'll've": "what will have",
    "what're": "what are",
    "what's": "what is",
    "what've": "what have",
    "when's": "when is",
    "when've": "when have",
    "where'd": "where did",
    "where's": "where is",
    "where've": "where have",
    "who'll": "who will",
    "who'll've": "who will have",
    "who's": "who is",
    "who've": "who have",
    "why's": "why is",
    "why've": "why have",
    "will've": "will have",
    "won't": "will not",
    "won't've": "will not have",
    "would've": "would have",
    "wouldn't": "would not",
    "wouldn't've": "would not have",
    "y'all": "you all",
    "y'all'd": "you all would",
    "y'all'd've": "you all would have",
    "y'all're": "you all are",
    "y'all've": "you all have",
    "you'd": "you would",
    "you'd've": "you would have",
    "you'll": "you will",
    "you'll've": "you will have",
    "you're": "you are",
    "you've": "you have"
    }

    q_decontracted = []

    for word in q.split():
        if word in contractions:
            word = contractions[word]

        q_decontracted.append(word)

    q = ' '.join(q_decontracted)
    q = q.replace("'ve", " have")
    q = q.replace("n't", " not")
    q = q.replace("'re", " are")
    q = q.replace("'ll", " will")

    # Removing HTML tags
    q = BeautifulSoup(q)
    q = q.get_text()

    # Remove punctuations
    pattern = re.compile('\W')
    q = re.sub(pattern, ' ', q).strip()


    return q

# %%
new_df['question1'] = new_df['question1'].apply(preprocess)
new_df['question2'] = new_df['question2'].apply(preprocess)

# %%
new_df['q1_num_words'] = new_df['question1'].apply(lambda row: len(row.split(" ")))
new_df['q2_num_words'] = new_df['question2'].apply(lambda row: len(row.split(" ")))
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_num_words  q2_num_words
# 398782            13            13
# 115086            13            16
# 327711            28            21
# 367788            14            32
# 151235             5             9

# %%
def common_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))
    return len(w1 & w2)

# %%
new_df['word_common'] = new_df.apply(common_words, axis=1)
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_num_words  q2_num_words  word_common
# 398782            13            13           12
# 115086            13            16            8
# 327711            28            21            4
# 367788            14            32            1
# 151235             5             9            3

# %%
def total_words(row):
    w1 = set(map(lambda word: word.lower().strip(), row['question1'].split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), row['question2'].split(" ")))
    return (len(w1) + len(w2))

# %%
new_df['word_total'] = new_df.apply(total_words, axis=1)
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_num_words  q2_num_words  word_common  word_total
# 398782            13            13           12          26
# 115086            13            16            8          24
# 327711            28            21            4          38
# 367788            14            32            1          34
# 151235             5             9            3          13

# %%
new_df['word_share'] = round(new_df['word_common']/new_df['word_total'],2)
new_df.head()
# Out:
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_num_words  q2_num_words  word_common  word_total  word_share
# 398782            13            13           12          26        0.46
# 115086            13            16            8          24        0.33
# 327711            28            21            4          38        0.11
# 367788            14            32            1          34        0.03
# 151235             5             9            3          13        0.23

# %%
# Advanced Features
from nltk.corpus import stopwords

def fetch_token_features(row):

    q1 = row['question1']
    q2 = row['question2']

    SAFE_DIV = 0.0001

    STOP_WORDS = stopwords.words("english")

    token_features = [0.0]*8

    # Converting the Sentence into Tokens:
    q1_tokens = q1.split()
    q2_tokens = q2.split()

    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])

    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])

    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))

    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))

    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))


    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)

    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])

    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])

    return token_features

# %%
import nltk
nltk.download('stopwords')
token_features = new_df.apply(fetch_token_features, axis=1)

new_df["cwc_min"]       = list(map(lambda x: x[0], token_features))
new_df["cwc_max"]       = list(map(lambda x: x[1], token_features))
new_df["csc_min"]       = list(map(lambda x: x[2], token_features))
new_df["csc_max"]       = list(map(lambda x: x[3], token_features))
new_df["ctc_min"]       = list(map(lambda x: x[4], token_features))
new_df["ctc_max"]       = list(map(lambda x: x[5], token_features))
new_df["last_word_eq"]  = list(map(lambda x: x[6], token_features))
new_df["first_word_eq"] = list(map(lambda x: x[7], token_features))
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.

# %%
# !pip install distance
import distance

def fetch_length_features(row):

    q1 = row['question1']
    q2 = row['question2']

    length_features = [0.0]*3

    # Converting the Sentence into Tokens:
    q1_tokens = q1.split()
    q2_tokens = q2.split()

    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features

    # Absolute length features
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))

    #Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens))/2

    strs = list(distance.lcsubstrings(q1, q2))
    length_features[2] = len(strs[0]) / (min(len(q1), len(q2)) + 1)

    return length_features
# Out:
# Collecting distance
#   Downloading Distance-0.1.3.tar.gz (180 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 180.3/180.3 kB 9.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: distance
#   Building wheel for distance (setup.py) ... done
#   Created wheel for distance: filename=Distance-0.1.3-py3-none-any.whl size=16256 sha256=e9efc2560ac7df4763bb4fbe64a72689b6a781b33fad1034d2b58c58863a2d86
#   Stored in directory: /root/.cache/pip/wheels/24/a8/58/407063d8e5c1d4dd6594c99d12baa0108570b56a92325587dd
# Successfully built distance
# Installing collected packages: distance
# Successfully installed distance-0.1.3

# %%
length_features = new_df.apply(fetch_length_features, axis=1)

new_df['abs_len_diff'] = list(map(lambda x: x[0], length_features))
new_df['mean_len'] = list(map(lambda x: x[1], length_features))
new_df['longest_substr_ratio'] = list(map(lambda x: x[2], length_features))

# %%
# !pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0

# %%
# Fuzzy Features
from fuzzywuzzy import fuzz

def fetch_fuzzy_features(row):

    q1 = row['question1']
    q2 = row['question2']

    fuzzy_features = [0.0]*4

    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
fuzzy_features = new_df.apply(fetch_fuzzy_features, axis=1)

# Creating new feature columns for fuzzy features
new_df['fuzz_ratio'] = list(map(lambda x: x[0], fuzzy_features))
new_df['fuzz_partial_ratio'] = list(map(lambda x: x[1], fuzzy_features))
new_df['token_sort_ratio'] = list(map(lambda x: x[2], fuzzy_features))
new_df['token_set_ratio'] = list(map(lambda x: x[3], fuzzy_features))

# %%
print(new_df.shape)
new_df.head()
# Out:
# (20000, 26)
#             id    qid1    qid2  \
# 398782  398782  496695  532029
# 115086  115086  187729  187730
# 327711  327711  454161  454162
# 367788  367788  498109  491396
# 151235  151235  237843   50930
#
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2  is_duplicate  \
# 398782  what is the best marketing automation tool for...             1
# 115086  i am quite poor and i want to be very rich  wh...             0
# 327711  t i e t to thapar university to thapar univers...             0
# 367788  my boyfriend doesnt feel guilty when he hurts ...             0
# 151235  what was the reason behind the bhopal gas tragedy             0
#
#         q1_num_words  q2_num_words  word_common  word_total  ...   ctc_max  \
# 398782            13            13           12          26  ...  0.923070
# 115086            13            16            8          24  ...  0.466664
# 327711            28            21            4          38  ...  0.115384
# 367788            14            32            1          34  ...  0.000000
# 151235             5             9            3          13  ...  0.333330
#
#         last_word_eq  first_word_eq  abs_len_diff  mean_len  \
# 398782             1              1             0      13.0
# 115086             1              1             3      13.5
# 327711             0              0             6      23.0
# 367788             0              0            17      21.5
# 151235             1              0             4       7.0
#
#         longest_substr_ratio  fuzz_ratio  fuzz_partial_ratio  \
# 398782              0.855263          99                  99
# 115086              0.224490          69                  67
# 327711              0.047619          26                  29
# 367788              0.050847          29                  41
# 151235              0.542857          55                  70
#
#         token_sort_ratio  token_set_ratio
# 398782                99               99
# 115086                65               74
# 327711                34               43
# 367788                23               30
# 151235                48               69
#
# [5 rows x 26 columns]

# %%
sns.pairplot(new_df[['ctc_min', 'cwc_min', 'csc_min', 'is_duplicate']],hue='is_duplicate')

# %%
# Using TSNE for Dimentionality reduction for 15 Features(Generated after cleaning the data) to 3 dimention

from sklearn.preprocessing import MinMaxScaler

X = MinMaxScaler().fit_transform(new_df[['cwc_min', 'cwc_max', 'csc_min', 'csc_max' , 'ctc_min' , 'ctc_max' , 'last_word_eq', 'first_word_eq' , 'abs_len_diff' , 'mean_len' , 'token_set_ratio' , 'token_sort_ratio' ,  'fuzz_ratio' , 'fuzz_partial_ratio' , 'longest_substr_ratio']])
y = new_df['is_duplicate'].values

# %%
from sklearn.manifold import TSNE

tsne2d = TSNE(
    n_components=2,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 20000 samples in 0.196s...
# [t-SNE] Computed neighbors for 20000 samples in 9.226s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 20000
# [t-SNE] Computed conditional probabilities for sample 2000 / 20000
# [t-SNE] Computed conditional probabilities for sample 3000 / 20000
# [t-SNE] Computed conditional probabilities for sample 4000 / 20000
# [t-SNE] Computed conditional probabilities for sample 5000 / 20000
# [t-SNE] Computed conditional probabilities for sample 6000 / 20000
# [t-SNE] Computed conditional probabilities for sample 7000 / 20000
# [t-SNE] Computed conditional probabilities for sample 8000 / 20000
# [t-SNE] Computed conditional probabilities for sample 9000 / 20000
# [t-SNE] Computed conditional probabilities for sample 10000 / 20000
# [t-SNE] Computed conditional probabilities for sample 11000 / 20000
# [t-SNE] Computed conditional probabilities for sample 12000 / 20000
# [t-SNE] Computed conditional probabilities for sample 13000 / 20000
# [t-SNE] Computed conditional probabilities for sample 14000 / 20000
# [t-SNE] Computed conditional probabilities for sample 15000 / 20000
# [t-SNE] Computed conditional probabilities for sample 16000 / 20000
# [t-SNE] Computed conditional probabilities for sample 17000 / 20000
# [t-SNE] Computed conditional probabilities for sample 18000 / 20000
# [t-SNE] Computed conditional probabilities for sample 19000 / 20000
# [t-SNE] Computed conditional probabilities for sample 20000 / 20000
# [t-SNE] Mean sigma: 0.098587
# [t-SNE] Computed conditional probabilities in 0.660s
# [t-SNE] Iteration 50: error = 104.1313629, gradient norm = 0.0333578 (50 iterations in 35.406s)
# [t-SNE] Iteration 100: error = 84.6675110, gradient norm = 0.0084545 (50 iterations in 13.497s)
# [t-SNE] Iteration 150: error = 81.2949982, gradient norm = 0.0049541 (50 iterations in 13.276s)
# [t-SNE] Iteration 200: error = 79.8771591, gradient norm = 0.0035302 (50 iterations in 13.240s)
# [t-SNE] Iteration 250: error = 79.0599823, gradient norm = 0.0027290 (50 iterations in 14.455s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 79.059982
# [t-SNE] Iteration 300: error = 3.0807965, gradient norm = 0.0087390 (50 iterations in 16.671s)
# [t-SNE] Iteration 350: error = 2.5078487, gradient norm = 0.0086160 (50 iterations in 12.476s)
# [t-SNE] Iteration 400: error = 2.2022982, gradient norm = 0.0079752 (50 iterations in 12.338s)
# [t-SNE] Iteration 450: error = 2.0143464, gradient norm = 0.0074384 (50 iterations in 12.378s)
# [t-SNE] Iteration 500: error = 1.8867522, gradient norm = 0.0069820 (50 iterations in 12.473s)
# [t-SNE] Iteration 550: error = 1.7947518, gradient norm = 0.0066043 (50 iterations in 12.502s)
# [t-SNE] Iteration 600: error = 1.7253098, gradient norm = 0.0062462 (50 iterations in 12.572s)
# [t-SNE] Iteration 650: error = 1.6715862, gradient norm = 0.0058271 (50 iterations in 12.554s)
# [t-SNE] Iteration 700: error = 1.6295208, gradient norm = 0.0053615 (50 iterations in 12.583s)
# [t-SNE] Iteration 750: error = 1.5958545, gradient norm = 0.0050260 (50 iterations in 13.882s)
# [t-SNE] Iteration 800: error = 1.5682896, gradient norm = 0.0046732 (50 iterations in 12.676s)
# [t-SNE] Iteration 850: error = 1.5456072, gradient norm = 0.0043274 (50 iterations in 12.662s)
# [t-SNE] Iteration 900: error = 1.5267323, gradient norm = 0.0039635 (50 iterations in 12.685s)
# [t-SNE] Iteration 950: error = 1.5110245, gradient norm = 0.0036292 (50 iterations in 12.723s)
# [t-SNE] Iteration 1000: error = 1.4977901, gradient norm = 0.0033227 (50 iterations in 12.783s)
# [t-SNE] KL divergence after 1000 iterations: 1.497790

# %%
x_df = pd.DataFrame({'x':tsne2d[:,0], 'y':tsne2d[:,1] ,'label':y})

# draw the plot in appropriate place in the grid
sns.lmplot(data=x_df, x='x', y='y', hue='label', fit_reg=False, height=8,palette="Set1",markers=['s','o'])

# %%
tsne3d = TSNE(
    n_components=3,
    init='random', # pca
    random_state=101,
    method='barnes_hut',
    n_iter=1000,
    verbose=2,
    angle=0.5
).fit_transform(X)
# Out:
# [t-SNE] Computing 91 nearest neighbors...
# [t-SNE] Indexed 20000 samples in 0.095s...
# [t-SNE] Computed neighbors for 20000 samples in 4.782s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 20000
# [t-SNE] Computed conditional probabilities for sample 2000 / 20000
# [t-SNE] Computed conditional probabilities for sample 3000 / 20000
# [t-SNE] Computed conditional probabilities for sample 4000 / 20000
# [t-SNE] Computed conditional probabilities for sample 5000 / 20000
# [t-SNE] Computed conditional probabilities for sample 6000 / 20000
# [t-SNE] Computed conditional probabilities for sample 7000 / 20000
# [t-SNE] Computed conditional probabilities for sample 8000 / 20000
# [t-SNE] Computed conditional probabilities for sample 9000 / 20000
# [t-SNE] Computed conditional probabilities for sample 10000 / 20000
# [t-SNE] Computed conditional probabilities for sample 11000 / 20000
# [t-SNE] Computed conditional probabilities for sample 12000 / 20000
# [t-SNE] Computed conditional probabilities for sample 13000 / 20000
# [t-SNE] Computed conditional probabilities for sample 14000 / 20000
# [t-SNE] Computed conditional probabilities for sample 15000 / 20000
# [t-SNE] Computed conditional probabilities for sample 16000 / 20000
# [t-SNE] Computed conditional probabilities for sample 17000 / 20000
# [t-SNE] Computed conditional probabilities for sample 18000 / 20000
# [t-SNE] Computed conditional probabilities for sample 19000 / 20000
# [t-SNE] Computed conditional probabilities for sample 20000 / 20000
# [t-SNE] Mean sigma: 0.098587
# [t-SNE] Computed conditional probabilities in 0.605s
# [t-SNE] Iteration 50: error = 105.1970215, gradient norm = 0.0187910 (50 iterations in 62.453s)
# [t-SNE] Iteration 100: error = 82.7266541, gradient norm = 0.0050856 (50 iterations in 36.554s)
# [t-SNE] Iteration 150: error = 79.9630127, gradient norm = 0.0025097 (50 iterations in 31.869s)
# [t-SNE] Iteration 200: error = 78.9209671, gradient norm = 0.0016341 (50 iterations in 31.517s)
# [t-SNE] Iteration 250: error = 78.3528519, gradient norm = 0.0012583 (50 iterations in 31.349s)
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 78.352852
# [t-SNE] Iteration 300: error = 2.7018409, gradient norm = 0.0044468 (50 iterations in 41.172s)
# [t-SNE] Iteration 350: error = 2.1394875, gradient norm = 0.0035659 (50 iterations in 46.653s)
# [t-SNE] Iteration 400: error = 1.8561208, gradient norm = 0.0028295 (50 iterations in 45.109s)
# [t-SNE] Iteration 450: error = 1.6911478, gradient norm = 0.0023413 (50 iterations in 46.340s)
# [t-SNE] Iteration 500: error = 1.5835462, gradient norm = 0.0020080 (50 iterations in 45.747s)
# [t-SNE] Iteration 550: error = 1.5083511, gradient norm = 0.0017350 (50 iterations in 45.845s)
# [t-SNE] Iteration 600: error = 1.4537892, gradient norm = 0.0015089 (50 iterations in 45.961s)
# [t-SNE] Iteration 650: error = 1.4145122, gradient norm = 0.0012572 (50 iterations in 45.130s)
# [t-SNE] Iteration 700: error = 1.3875009, gradient norm = 0.0009567 (50 iterations in 46.154s)
# [t-SNE] Iteration 750: error = 1.3694792, gradient norm = 0.0007325 (50 iterations in 45.424s)
# [t-SNE] Iteration 800: error = 1.3564368, gradient norm = 0.0005843 (50 iterations in 46.246s)
# [t-SNE] Iteration 850: error = 1.3462361, gradient norm = 0.0005239 (50 iterations in 46.072s)
# [t-SNE] Iteration 900: error = 1.3376937, gradient norm = 0.0004453 (50 iterations in 45.998s)
# [t-SNE] Iteration 950: error = 1.3300698, gradient norm = 0.0004045 (50 iterations in 46.508s)
# [t-SNE] Iteration 1000: error = 1.3235456, gradient norm = 0.0003701 (50 iterations in 45.587s)
# [t-SNE] KL divergence after 1000 iterations: 1.323546

# %%
ques_df = new_df[['question1','question2']]
ques_df.head()
# Out:
#                                                 question1  \
# 398782  what is the best marketing automation tool for...
# 115086   i am poor but i want to invest  what should i do
# 327711  i am from india and live abroad  i met a guy f...
# 367788  why do so many people in the u s  hate the sou...
# 151235                 consequences of bhopal gas tragedy
#
#                                                 question2
# 398782  what is the best marketing automation tool for...
# 115086  i am quite poor and i want to be very rich  wh...
# 327711  t i e t to thapar university to thapar univers...
# 367788  my boyfriend doesnt feel guilty when he hurts ...
# 151235  what was the reason behind the bhopal gas tragedy

# %%
final_df = new_df.drop(columns=['id','qid1','qid2','question1','question2'])
print(final_df.shape)
final_df.head()
# Out:
# (20000, 21)
#         is_duplicate  q1_num_words  q2_num_words  word_common  word_total  \
# 398782             1            13            13           12          26
# 115086             0            13            16            8          24
# 327711             0            28            21            4          38
# 367788             0            14            32            1          34
# 151235             0             5             9            3          13
#
#         word_share   cwc_min   cwc_max   csc_min   csc_max  ...   ctc_max  \
# 398782        0.46  0.874989  0.874989  0.999980  0.999980  ...  0.923070
# 115086        0.33  0.666644  0.499988  0.714276  0.624992  ...  0.466664
# 327711        0.11  0.000000  0.000000  0.428565  0.272725  ...  0.115384
# 367788        0.03  0.000000  0.000000  0.000000  0.000000  ...  0.000000
# 151235        0.23  0.749981  0.599988  0.000000  0.000000  ...  0.333330
#
#         last_word_eq  first_word_eq  abs_len_diff  mean_len  \
# 398782             1              1             0      13.0
# 115086             1              1             3      13.5
# 327711             0              0             6      23.0
# 367788             0              0            17      21.5
# 151235             1              0             4       7.0
#
#         longest_substr_ratio  fuzz_ratio  fuzz_partial_ratio  \
# 398782              0.855263          99                  99
# 115086              0.224490          69                  67
# 327711              0.047619          26                  29
# 367788              0.050847          29                  41
# 151235              0.542857          55                  70
#
#         token_sort_ratio  token_set_ratio
# 398782                99               99
# 115086                65               74
# 327711                34               43
# 367788                23               30
# 151235                48               69
#
# [5 rows x 21 columns]

# %%
# bow
from sklearn.feature_extraction.text import CountVectorizer
# merge texts
questions = list(ques_df['question1']) + list(ques_df['question2'])

cv = CountVectorizer(max_features=3000)
q1_arr, q2_arr = np.vsplit(cv.fit_transform(questions).toarray(),2)

# %%
temp_df1 = pd.DataFrame(q1_arr, index= ques_df.index)
temp_df2 = pd.DataFrame(q2_arr, index= ques_df.index)
temp_df = pd.concat([temp_df1, temp_df2], axis=1)
temp_df.shape
# Out:
# (20000, 6000)

# %%
final_df = pd.concat([final_df, temp_df], axis=1)
print(final_df.shape)
final_df.head()
# Out:
# (20000, 6021)
#         is_duplicate  q1_num_words  q2_num_words  word_common  word_total  \
# 398782             1            13            13           12          26
# 115086             0            13            16            8          24
# 327711             0            28            21            4          38
# 367788             0            14            32            1          34
# 151235             0             5             9            3          13
#
#         word_share   cwc_min   cwc_max   csc_min   csc_max  ...  2990  2991  \
# 398782        0.46  0.874989  0.874989  0.999980  0.999980  ...     0     0
# 115086        0.33  0.666644  0.499988  0.714276  0.624992  ...     0     0
# 327711        0.11  0.000000  0.000000  0.428565  0.272725  ...     0     0
# 367788        0.03  0.000000  0.000000  0.000000  0.000000  ...     0     0
# 151235        0.23  0.749981  0.599988  0.000000  0.000000  ...     0     0
#
#         2992  2993  2994  2995  2996  2997  2998  2999
# 398782     0     0     0     0     0     0     0     0
# 115086     0     0     0     0     0     0     0     0
# 327711     0     0     0     0     0     0     0     0
# 367788     0     1     0     0     0     0     0     0
# 151235     0     0     0     0     0     0     0     0
#
# [5 rows x 6021 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(final_df.iloc[:,1:].values,final_df.iloc[:,0].values,test_size=0.2,random_state=1)

# %%
# random forest
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
rf = RandomForestClassifier()
rf.fit(X_train,y_train)
y_pred = rf.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.78375

# %%
# logistic regression
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression()
lr.fit(X_train,y_train)
y_pred = lr.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.729

# %%
# xgboost
from xgboost import XGBClassifier
xgb = XGBClassifier()
xgb.fit(X_train,y_train)
y_pred = xgb.predict(X_test)
accuracy_score(y_test,y_pred)
# Out:
# 0.79075

# %%
from sklearn.metrics import confusion_matrix
# for random forest model
confusion_matrix(y_test,y_pred)
# Out:
# array([[2125,  403],
#        [ 434, 1038]])

# %% [markdown]
# **Hyper parameter Tunning**

# %%
from sklearn.model_selection import RandomizedSearchCV
from scipy.stats import randint, uniform

# %%
param_dist = {
    'n_estimators': randint(100, 1000),
    'max_depth': randint(3, 13),
    'learning_rate': uniform(0.01, 0.3),
    'subsample': uniform(0.6, 0.4),
    'colsample_bytree': uniform(0.6, 0.4),
    'gamma': uniform(0, 5),
    'min_child_weight': randint(1, 10),
    'reg_alpha': uniform(0, 5),
    'reg_lambda': uniform(0, 5)
}

# %%
random_search = RandomizedSearchCV(
    estimator=xgb,
    param_distributions=param_dist,
    n_iter=30,
    scoring='accuracy',
    cv=5,
    verbose=2,
    random_state=42
)

random_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 30 candidates, totalling 150 fits
# [CV] END colsample_bytree=0.749816047538945, gamma=4.75357153204958, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=7, n_estimators=221, reg_alpha=0.7799726016810132, reg_lambda=0.2904180608409973, subsample=0.9464704583099741; total time=  33.9s
# [CV] END colsample_bytree=0.749816047538945, gamma=4.75357153204958, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=7, n_estimators=221, reg_alpha=0.7799726016810132, reg_lambda=0.2904180608409973, subsample=0.9464704583099741; total time=  29.4s
# [CV] END colsample_bytree=0.749816047538945, gamma=4.75357153204958, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=7, n_estimators=221, reg_alpha=0.7799726016810132, reg_lambda=0.2904180608409973, subsample=0.9464704583099741; total time=  28.8s
# [CV] END colsample_bytree=0.749816047538945, gamma=4.75357153204958, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=7, n_estimators=221, reg_alpha=0.7799726016810132, reg_lambda=0.2904180608409973, subsample=0.9464704583099741; total time=  28.7s
# [CV] END colsample_bytree=0.749816047538945, gamma=4.75357153204958, learning_rate=0.22959818254342154, max_depth=7, min_child_weight=7, n_estimators=221, reg_alpha=0.7799726016810132, reg_lambda=0.2904180608409973, subsample=0.9464704583099741; total time=  28.5s
# [CV] END colsample_bytree=0.8404460046972835, gamma=3.540362888980227, learning_rate=0.016175348288740735, max_depth=4, min_child_weight=8, n_estimators=591, reg_alpha=4.692763545078751, reg_lambda=0.0038938292050716417, subsample=0.996884623716487; total time= 1.3min
# [CV] END colsample_bytree=0.8404460046972835, gamma=3.540362888980227, learning_rate=0.016175348288740735, max_depth=4, min_child_weight=8, n_estimators=591, reg_alpha=4.692763545078751, reg_lambda=0.0038938292050716417, subsample=0.996884623716487; total time= 1.3min
# [CV] END colsample_bytree=0.8404460046972835, gamma=3.540362888980227, learning_rate=0.016175348288740735, max_depth=4, min_child_weight=8, n_estimators=591, reg_alpha=4.692763545078751, reg_lambda=0.0038938292050716417, subsample=0.996884623716487; total time= 1.3min
# [CV] END colsample_bytree=0.8404460046972835, gamma=3.540362888980227, learning_rate=0.016175348288740735, max_depth=4, min_child_weight=8, n_estimators=591, reg_alpha=4.692763545078751, reg_lambda=0.0038938292050716417, subsample=0.996884623716487; total time= 1.3min
# [CV] END colsample_bytree=0.8404460046972835, gamma=3.540362888980227, learning_rate=0.016175348288740735, max_depth=4, min_child_weight=8, n_estimators=591, reg_alpha=4.692763545078751, reg_lambda=0.0038938292050716417, subsample=0.996884623716487; total time= 1.3min
# [CV] END colsample_bytree=0.8469926038510867, gamma=3.0582658024414044, learning_rate=0.012119891565915222, max_depth=11, min_child_weight=1, n_estimators=574, reg_alpha=3.0592644736118975, reg_lambda=0.6974693032602092, subsample=0.7168578594140873; total time= 1.9min
# [CV] END colsample_bytree=0.8469926038510867, gamma=3.0582658024414044, learning_rate=0.012119891565915222, max_depth=11, min_child_weight=1, n_estimators=574, reg_alpha=3.0592644736118975, reg_lambda=0.6974693032602092, subsample=0.7168578594140873; total time= 1.9min
# [CV] END colsample_bytree=0.8469926038510867, gamma=3.0582658024414044, learning_rate=0.012119891565915222, max_depth=11, min_child_weight=1, n_estimators=574, reg_alpha=3.0592644736118975, reg_lambda=0.6974693032602092, subsample=0.7168578594140873; total time= 1.8min
# [CV] END colsample_bytree=0.8469926038510867, gamma=3.0582658024414044, learning_rate=0.012119891565915222, max_depth=11, min_child_weight=1, n_estimators=574, reg_alpha=3.0592644736118975, reg_lambda=0.6974693032602092, subsample=0.7168578594140873; total time= 1.9min
# [CV] END colsample_bytree=0.8469926038510867, gamma=3.0582658024414044, learning_rate=0.012119891565915222, max_depth=11, min_child_weight=1, n_estimators=574, reg_alpha=3.0592644736118975, reg_lambda=0.6974693032602092, subsample=0.7168578594140873; total time= 1.8min
# [CV] END colsample_bytree=0.7465447373174767, gamma=2.28034992108518, learning_rate=0.24555278841790407, max_depth=5, min_child_weight=4, n_estimators=666, reg_alpha=4.916154429033941, reg_lambda=2.3338144662398994, subsample=0.9439761626945282; total time= 1.1min
# [CV] END colsample_bytree=0.7465447373174767, gamma=2.28034992108518, learning_rate=0.24555278841790407, max_depth=5, min_child_weight=4, n_estimators=666, reg_alpha=4.916154429033941, reg_lambda=2.3338144662398994, subsample=0.9439761626945282; total time= 1.1min
# [CV] END colsample_bytree=0.7465447373174767, gamma=2.28034992108518, learning_rate=0.24555278841790407, max_depth=5, min_child_weight=4, n_estimators=666, reg_alpha=4.916154429033941, reg_lambda=2.3338144662398994, subsample=0.9439761626945282; total time= 1.1min
# [CV] END colsample_bytree=0.7465447373174767, gamma=2.28034992108518, learning_rate=0.24555278841790407, max_depth=5, min_child_weight=4, n_estimators=666, reg_alpha=4.916154429033941, reg_lambda=2.3338144662398994, subsample=0.9439761626945282; total time= 1.1min
# [CV] END colsample_bytree=0.7465447373174767, gamma=2.28034992108518, learning_rate=0.24555278841790407, max_depth=5, min_child_weight=4, n_estimators=666, reg_alpha=4.916154429033941, reg_lambda=2.3338144662398994, subsample=0.9439761626945282; total time= 1.1min
# [CV] END colsample_bytree=0.8721230154351118, gamma=2.2524962598477147, learning_rate=0.013979488347959958, max_depth=11, min_child_weight=4, n_estimators=113, reg_alpha=4.041986740582305, reg_lambda=1.5230688458668533, subsample=0.6390688456025535; total time=  33.9s
# [CV] END colsample_bytree=0.8721230154351118, gamma=2.2524962598477147, learning_rate=0.013979488347959958, max_depth=11, min_child_weight=4, n_estimators=113, reg_alpha=4.041986740582305, reg_lambda=1.5230688458668533, subsample=0.6390688456025535; total time=  34.7s
# [CV] END colsample_bytree=0.8721230154351118, gamma=2.2524962598477147, learning_rate=0.013979488347959958, max_depth=11, min_child_weight=4, n_estimators=113, reg_alpha=4.041986740582305, reg_lambda=1.5230688458668533, subsample=0.6390688456025535; total time=  32.8s
# [CV] END colsample_bytree=0.8721230154351118, gamma=2.2524962598477147, learning_rate=0.013979488347959958, max_depth=11, min_child_weight=4, n_estimators=113, reg_alpha=4.041986740582305, reg_lambda=1.5230688458668533, subsample=0.6390688456025535; total time=  33.5s
# [CV] END colsample_bytree=0.8721230154351118, gamma=2.2524962598477147, learning_rate=0.013979488347959958, max_depth=11, min_child_weight=4, n_estimators=113, reg_alpha=4.041986740582305, reg_lambda=1.5230688458668533, subsample=0.6390688456025535; total time=  32.3s
# [CV] END colsample_bytree=0.8736932106048627, gamma=2.2007624686980067, learning_rate=0.04661147045343365, max_depth=10, min_child_weight=7, n_estimators=134, reg_alpha=4.546602010393911, reg_lambda=1.2938999080000846, subsample=0.8650089137415928; total time=  33.5s
# [CV] END colsample_bytree=0.8736932106048627, gamma=2.2007624686980067, learning_rate=0.04661147045343365, max_depth=10, min_child_weight=7, n_estimators=134, reg_alpha=4.546602010393911, reg_lambda=1.2938999080000846, subsample=0.8650089137415928; total time=  32.1s
# [CV] END colsample_bytree=0.8736932106048627, gamma=2.2007624686980067, learning_rate=0.04661147045343365, max_depth=10, min_child_weight=7, n_estimators=134, reg_alpha=4.546602010393911, reg_lambda=1.2938999080000846, subsample=0.8650089137415928; total time=  33.3s
# [CV] END colsample_bytree=0.8736932106048627, gamma=2.2007624686980067, learning_rate=0.04661147045343365, max_depth=10, min_child_weight=7, n_estimators=134, reg_alpha=4.546602010393911, reg_lambda=1.2938999080000846, subsample=0.8650089137415928; total time=  32.1s
# [CV] END colsample_bytree=0.8736932106048627, gamma=2.2007624686980067, learning_rate=0.04661147045343365, max_depth=10, min_child_weight=7, n_estimators=134, reg_alpha=4.546602010393911, reg_lambda=1.2938999080000846, subsample=0.8650089137415928; total time=  33.0s
# [CV] END colsample_bytree=0.7246844304357644, gamma=2.600340105889054, learning_rate=0.1740130838029839, max_depth=8, min_child_weight=5, n_estimators=802, reg_alpha=4.211423872974993, reg_lambda=2.248770666848828, subsample=0.7580600944007257; total time= 1.4min
# [CV] END colsample_bytree=0.7246844304357644, gamma=2.600340105889054, learning_rate=0.1740130838029839, max_depth=8, min_child_weight=5, n_estimators=802, reg_alpha=4.211423872974993, reg_lambda=2.248770666848828, subsample=0.7580600944007257; total time= 1.4min
# [CV] END colsample_bytree=0.7246844304357644, gamma=2.600340105889054, learning_rate=0.1740130838029839, max_depth=8, min_child_weight=5, n_estimators=802, reg_alpha=4.211423872974993, reg_lambda=2.248770666848828, subsample=0.7580600944007257; total time= 1.4min
# [CV] END colsample_bytree=0.7246844304357644, gamma=2.600340105889054, learning_rate=0.1740130838029839, max_depth=8, min_child_weight=5, n_estimators=802, reg_alpha=4.211423872974993, reg_lambda=2.248770666848828, subsample=0.7580600944007257; total time= 1.4min
# [CV] END colsample_bytree=0.7246844304357644, gamma=2.600340105889054, learning_rate=0.1740130838029839, max_depth=8, min_child_weight=5, n_estimators=802, reg_alpha=4.211423872974993, reg_lambda=2.248770666848828, subsample=0.7580600944007257; total time= 1.4min
# [CV] END colsample_bytree=0.9706635463175177, gamma=3.6363599792821044, learning_rate=0.1079622306417506, max_depth=9, min_child_weight=4, n_estimators=801, reg_alpha=1.6266516538163218, reg_lambda=1.9433864484474102, subsample=0.7085396127095583; total time= 1.4min
# [CV] END colsample_bytree=0.9706635463175177, gamma=3.6363599792821044, learning_rate=0.1079622306417506, max_depth=9, min_child_weight=4, n_estimators=801, reg_alpha=1.6266516538163218, reg_lambda=1.9433864484474102, subsample=0.7085396127095583; total time= 1.4min
# [CV] END colsample_bytree=0.9706635463175177, gamma=3.6363599792821044, learning_rate=0.1079622306417506, max_depth=9, min_child_weight=4, n_estimators=801, reg_alpha=1.6266516538163218, reg_lambda=1.9433864484474102, subsample=0.7085396127095583; total time= 1.4min
# [CV] END colsample_bytree=0.9706635463175177, gamma=3.6363599792821044, learning_rate=0.1079622306417506, max_depth=9, min_child_weight=4, n_estimators=801, reg_alpha=1.6266516538163218, reg_lambda=1.9433864484474102, subsample=0.7085396127095583; total time= 1.4min
# [CV] END colsample_bytree=0.9706635463175177, gamma=3.6363599792821044, learning_rate=0.1079622306417506, max_depth=9, min_child_weight=4, n_estimators=801, reg_alpha=1.6266516538163218, reg_lambda=1.9433864484474102, subsample=0.7085396127095583; total time= 1.4min
# [CV] END colsample_bytree=0.9314950036607718, gamma=1.7837666334679465, learning_rate=0.09428035290621423, max_depth=11, min_child_weight=5, n_estimators=114, reg_alpha=0.8263346953150125, reg_lambda=0.07818203370596966, subsample=0.7693605922825478; total time=  27.9s
# [CV] END colsample_bytree=0.9314950036607718, gamma=1.7837666334679465, learning_rate=0.09428035290621423, max_depth=11, min_child_weight=5, n_estimators=114, reg_alpha=0.8263346953150125, reg_lambda=0.07818203370596966, subsample=0.7693605922825478; total time=  28.2s
# [CV] END colsample_bytree=0.9314950036607718, gamma=1.7837666334679465, learning_rate=0.09428035290621423, max_depth=11, min_child_weight=5, n_estimators=114, reg_alpha=0.8263346953150125, reg_lambda=0.07818203370596966, subsample=0.7693605922825478; total time=  27.9s
# [CV] END colsample_bytree=0.9314950036607718, gamma=1.7837666334679465, learning_rate=0.09428035290621423, max_depth=11, min_child_weight=5, n_estimators=114, reg_alpha=0.8263346953150125, reg_lambda=0.07818203370596966, subsample=0.7693605922825478; total time=  27.5s
# [CV] END colsample_bytree=0.9314950036607718, gamma=1.7837666334679465, learning_rate=0.09428035290621423, max_depth=11, min_child_weight=5, n_estimators=114, reg_alpha=0.8263346953150125, reg_lambda=0.07818203370596966, subsample=0.7693605922825478; total time=  27.7s
# [CV] END colsample_bytree=0.7579526072702278, gamma=1.4674408735901907, learning_rate=0.014223946814525337, max_depth=5, min_child_weight=1, n_estimators=491, reg_alpha=3.6450358402049368, reg_lambda=3.8563517334297286, subsample=0.6296178606936361; total time= 1.3min
# [CV] END colsample_bytree=0.7579526072702278, gamma=1.4674408735901907, learning_rate=0.014223946814525337, max_depth=5, min_child_weight=1, n_estimators=491, reg_alpha=3.6450358402049368, reg_lambda=3.8563517334297286, subsample=0.6296178606936361; total time= 1.3min
# [CV] END colsample_bytree=0.7579526072702278, gamma=1.4674408735901907, learning_rate=0.014223946814525337, max_depth=5, min_child_weight=1, n_estimators=491, reg_alpha=3.6450358402049368, reg_lambda=3.8563517334297286, subsample=0.6296178606936361; total time= 1.3min
# [CV] END colsample_bytree=0.7579526072702278, gamma=1.4674408735901907, learning_rate=0.014223946814525337, max_depth=5, min_child_weight=1, n_estimators=491, reg_alpha=3.6450358402049368, reg_lambda=3.8563517334297286, subsample=0.6296178606936361; total time= 1.3min
# [CV] END colsample_bytree=0.7579526072702278, gamma=1.4674408735901907, learning_rate=0.014223946814525337, max_depth=5, min_child_weight=1, n_estimators=491, reg_alpha=3.6450358402049368, reg_lambda=3.8563517334297286, subsample=0.6296178606936361; total time= 1.2min
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.5793452976256486, learning_rate=0.2689310277626781, max_depth=10, min_child_weight=4, n_estimators=132, reg_alpha=0.3177917514301182, reg_lambda=1.554911608578311, subsample=0.7300733288106989; total time=  32.7s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.5793452976256486, learning_rate=0.2689310277626781, max_depth=10, min_child_weight=4, n_estimators=132, reg_alpha=0.3177917514301182, reg_lambda=1.554911608578311, subsample=0.7300733288106989; total time=  30.9s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.5793452976256486, learning_rate=0.2689310277626781, max_depth=10, min_child_weight=4, n_estimators=132, reg_alpha=0.3177917514301182, reg_lambda=1.554911608578311, subsample=0.7300733288106989; total time=  32.6s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.5793452976256486, learning_rate=0.2689310277626781, max_depth=10, min_child_weight=4, n_estimators=132, reg_alpha=0.3177917514301182, reg_lambda=1.554911608578311, subsample=0.7300733288106989; total time=  31.4s
# [CV] END colsample_bytree=0.7433862914177091, gamma=0.5793452976256486, learning_rate=0.2689310277626781, max_depth=10, min_child_weight=4, n_estimators=132, reg_alpha=0.3177917514301182, reg_lambda=1.554911608578311, subsample=0.7300733288106989; total time=  32.7s
# [CV] END colsample_bytree=0.8918424713352255, gamma=3.1877873567760657, learning_rate=0.27616382277289797, max_depth=3, min_child_weight=3, n_estimators=712, reg_alpha=4.858560476945518, reg_lambda=4.24456912133042, subsample=0.8886918084659492; total time= 1.2min
# [CV] END colsample_bytree=0.8918424713352255, gamma=3.1877873567760657, learning_rate=0.27616382277289797, max_depth=3, min_child_weight=3, n_estimators=712, reg_alpha=4.858560476945518, reg_lambda=4.24456912133042, subsample=0.8886918084659492; total time= 1.2min
# [CV] END colsample_bytree=0.8918424713352255, gamma=3.1877873567760657, learning_rate=0.27616382277289797, max_depth=3, min_child_weight=3, n_estimators=712, reg_alpha=4.858560476945518, reg_lambda=4.24456912133042, subsample=0.8886918084659492; total time= 1.2min
# [CV] END colsample_bytree=0.8918424713352255, gamma=3.1877873567760657, learning_rate=0.27616382277289797, max_depth=3, min_child_weight=3, n_estimators=712, reg_alpha=4.858560476945518, reg_lambda=4.24456912133042, subsample=0.8886918084659492; total time= 1.2min
# [CV] END colsample_bytree=0.8918424713352255, gamma=3.1877873567760657, learning_rate=0.27616382277289797, max_depth=3, min_child_weight=3, n_estimators=712, reg_alpha=4.858560476945518, reg_lambda=4.24456912133042, subsample=0.8886918084659492; total time= 1.2min
# [CV] END colsample_bytree=0.6943939678995823, gamma=1.2803416138066197, learning_rate=0.022130076861529402, max_depth=12, min_child_weight=2, n_estimators=991, reg_alpha=0.5394571349665223, reg_lambda=0.15714592843367126, subsample=0.8545641645055122; total time= 2.6min
# [CV] END colsample_bytree=0.6943939678995823, gamma=1.2803416138066197, learning_rate=0.022130076861529402, max_depth=12, min_child_weight=2, n_estimators=991, reg_alpha=0.5394571349665223, reg_lambda=0.15714592843367126, subsample=0.8545641645055122; total time= 2.6min
# [CV] END colsample_bytree=0.6943939678995823, gamma=1.2803416138066197, learning_rate=0.022130076861529402, max_depth=12, min_child_weight=2, n_estimators=991, reg_alpha=0.5394571349665223, reg_lambda=0.15714592843367126, subsample=0.8545641645055122; total time= 2.6min
# [CV] END colsample_bytree=0.6943939678995823, gamma=1.2803416138066197, learning_rate=0.022130076861529402, max_depth=12, min_child_weight=2, n_estimators=991, reg_alpha=0.5394571349665223, reg_lambda=0.15714592843367126, subsample=0.8545641645055122; total time= 2.5min
# [CV] END colsample_bytree=0.6943939678995823, gamma=1.2803416138066197, learning_rate=0.022130076861529402, max_depth=12, min_child_weight=2, n_estimators=991, reg_alpha=0.5394571349665223, reg_lambda=0.15714592843367126, subsample=0.8545641645055122; total time= 2.6min
# [CV] END colsample_bytree=0.7257423924305306, gamma=2.542853455823514, learning_rate=0.2822699421778279, max_depth=9, min_child_weight=7, n_estimators=848, reg_alpha=2.6992054565083654, reg_lambda=1.015306123673847, subsample=0.9771414282231924; total time= 1.4min
# [CV] END colsample_bytree=0.7257423924305306, gamma=2.542853455823514, learning_rate=0.2822699421778279, max_depth=9, min_child_weight=7, n_estimators=848, reg_alpha=2.6992054565083654, reg_lambda=1.015306123673847, subsample=0.9771414282231924; total time= 1.3min
# [CV] END colsample_bytree=0.7257423924305306, gamma=2.542853455823514, learning_rate=0.2822699421778279, max_depth=9, min_child_weight=7, n_estimators=848, reg_alpha=2.6992054565083654, reg_lambda=1.015306123673847, subsample=0.9771414282231924; total time= 1.4min
# [CV] END colsample_bytree=0.7257423924305306, gamma=2.542853455823514, learning_rate=0.2822699421778279, max_depth=9, min_child_weight=7, n_estimators=848, reg_alpha=2.6992054565083654, reg_lambda=1.015306123673847, subsample=0.9771414282231924; total time= 1.4min
# [CV] END colsample_bytree=0.7257423924305306, gamma=2.542853455823514, learning_rate=0.2822699421778279, max_depth=9, min_child_weight=7, n_estimators=848, reg_alpha=2.6992054565083654, reg_lambda=1.015306123673847, subsample=0.9771414282231924; total time= 1.4min
# [CV] END colsample_bytree=0.8395461865954144, gamma=3.4739246651985227, learning_rate=0.2741403517045773, max_depth=12, min_child_weight=5, n_estimators=673, reg_alpha=3.1670187825521174, reg_lambda=4.357302950938589, subsample=0.9214688307596458; total time= 1.1min
# [CV] END colsample_bytree=0.8395461865954144, gamma=3.4739246651985227, learning_rate=0.2741403517045773, max_depth=12, min_child_weight=5, n_estimators=673, reg_alpha=3.1670187825521174, reg_lambda=4.357302950938589, subsample=0.9214688307596458; total time= 1.1min
# [CV] END colsample_bytree=0.8395461865954144, gamma=3.4739246651985227, learning_rate=0.2741403517045773, max_depth=12, min_child_weight=5, n_estimators=673, reg_alpha=3.1670187825521174, reg_lambda=4.357302950938589, subsample=0.9214688307596458; total time= 1.1min
# [CV] END colsample_bytree=0.8395461865954144, gamma=3.4739246651985227, learning_rate=0.2741403517045773, max_depth=12, min_child_weight=5, n_estimators=673, reg_alpha=3.1670187825521174, reg_lambda=4.357302950938589, subsample=0.9214688307596458; total time= 1.1min
# [CV] END colsample_bytree=0.8395461865954144, gamma=3.4739246651985227, learning_rate=0.2741403517045773, max_depth=12, min_child_weight=5, n_estimators=673, reg_alpha=3.1670187825521174, reg_lambda=4.357302950938589, subsample=0.9214688307596458; total time= 1.1min
# [CV] END colsample_bytree=0.6746280235544143, gamma=4.462794992449889, learning_rate=0.17180267257469523, max_depth=12, min_child_weight=7, n_estimators=447, reg_alpha=1.7814891903848746, reg_lambda=4.53414220772877, subsample=0.7088528997538541; total time=  51.1s
# [CV] END colsample_bytree=0.6746280235544143, gamma=4.462794992449889, learning_rate=0.17180267257469523, max_depth=12, min_child_weight=7, n_estimators=447, reg_alpha=1.7814891903848746, reg_lambda=4.53414220772877, subsample=0.7088528997538541; total time=  51.2s
# [CV] END colsample_bytree=0.6746280235544143, gamma=4.462794992449889, learning_rate=0.17180267257469523, max_depth=12, min_child_weight=7, n_estimators=447, reg_alpha=1.7814891903848746, reg_lambda=4.53414220772877, subsample=0.7088528997538541; total time=  50.8s
# [CV] END colsample_bytree=0.6746280235544143, gamma=4.462794992449889, learning_rate=0.17180267257469523, max_depth=12, min_child_weight=7, n_estimators=447, reg_alpha=1.7814891903848746, reg_lambda=4.53414220772877, subsample=0.7088528997538541; total time=  51.0s
# [CV] END colsample_bytree=0.6746280235544143, gamma=4.462794992449889, learning_rate=0.17180267257469523, max_depth=12, min_child_weight=7, n_estimators=447, reg_alpha=1.7814891903848746, reg_lambda=4.53414220772877, subsample=0.7088528997538541; total time=  50.6s
# [CV] END colsample_bytree=0.8590760482165449, gamma=0.002601884976579094, learning_rate=0.11577065690025069, max_depth=5, min_child_weight=7, n_estimators=809, reg_alpha=2.553736512887829, reg_lambda=2.087055015743895, subsample=0.6888431241882921; total time= 2.3min
# [CV] END colsample_bytree=0.8590760482165449, gamma=0.002601884976579094, learning_rate=0.11577065690025069, max_depth=5, min_child_weight=7, n_estimators=809, reg_alpha=2.553736512887829, reg_lambda=2.087055015743895, subsample=0.6888431241882921; total time= 2.2min
# [CV] END colsample_bytree=0.8590760482165449, gamma=0.002601884976579094, learning_rate=0.11577065690025069, max_depth=5, min_child_weight=7, n_estimators=809, reg_alpha=2.553736512887829, reg_lambda=2.087055015743895, subsample=0.6888431241882921; total time= 2.2min
# [CV] END colsample_bytree=0.8590760482165449, gamma=0.002601884976579094, learning_rate=0.11577065690025069, max_depth=5, min_child_weight=7, n_estimators=809, reg_alpha=2.553736512887829, reg_lambda=2.087055015743895, subsample=0.6888431241882921; total time= 2.2min
# [CV] END colsample_bytree=0.8590760482165449, gamma=0.002601884976579094, learning_rate=0.11577065690025069, max_depth=5, min_child_weight=7, n_estimators=809, reg_alpha=2.553736512887829, reg_lambda=2.087055015743895, subsample=0.6888431241882921; total time= 2.2min
# [CV] END colsample_bytree=0.6479461469334731, gamma=1.6880758570181398, learning_rate=0.29287291117375575, max_depth=8, min_child_weight=8, n_estimators=707, reg_alpha=2.790510010086706, reg_lambda=2.019180855290204, subsample=0.6259568988435926; total time= 1.5min
# [CV] END colsample_bytree=0.6479461469334731, gamma=1.6880758570181398, learning_rate=0.29287291117375575, max_depth=8, min_child_weight=8, n_estimators=707, reg_alpha=2.790510010086706, reg_lambda=2.019180855290204, subsample=0.6259568988435926; total time= 1.5min
# [CV] END colsample_bytree=0.6479461469334731, gamma=1.6880758570181398, learning_rate=0.29287291117375575, max_depth=8, min_child_weight=8, n_estimators=707, reg_alpha=2.790510010086706, reg_lambda=2.019180855290204, subsample=0.6259568988435926; total time= 1.6min
# [CV] END colsample_bytree=0.6479461469334731, gamma=1.6880758570181398, learning_rate=0.29287291117375575, max_depth=8, min_child_weight=8, n_estimators=707, reg_alpha=2.790510010086706, reg_lambda=2.019180855290204, subsample=0.6259568988435926; total time= 1.6min
# [CV] END colsample_bytree=0.6479461469334731, gamma=1.6880758570181398, learning_rate=0.29287291117375575, max_depth=8, min_child_weight=8, n_estimators=707, reg_alpha=2.790510010086706, reg_lambda=2.019180855290204, subsample=0.6259568988435926; total time= 1.6min
# [CV] END colsample_bytree=0.7015661655737379, gamma=1.234380314193006, learning_rate=0.21889128185193651, max_depth=5, min_child_weight=1, n_estimators=712, reg_alpha=1.424202471887338, reg_lambda=0.18443473677266398, subsample=0.8438257335919588; total time= 1.3min
# [CV] END colsample_bytree=0.7015661655737379, gamma=1.234380314193006, learning_rate=0.21889128185193651, max_depth=5, min_child_weight=1, n_estimators=712, reg_alpha=1.424202471887338, reg_lambda=0.18443473677266398, subsample=0.8438257335919588; total time= 1.3min
# [CV] END colsample_bytree=0.7015661655737379, gamma=1.234380314193006, learning_rate=0.21889128185193651, max_depth=5, min_child_weight=1, n_estimators=712, reg_alpha=1.424202471887338, reg_lambda=0.18443473677266398, subsample=0.8438257335919588; total time= 1.3min
# [CV] END colsample_bytree=0.7015661655737379, gamma=1.234380314193006, learning_rate=0.21889128185193651, max_depth=5, min_child_weight=1, n_estimators=712, reg_alpha=1.424202471887338, reg_lambda=0.18443473677266398, subsample=0.8438257335919588; total time= 1.3min
# [CV] END colsample_bytree=0.7015661655737379, gamma=1.234380314193006, learning_rate=0.21889128185193651, max_depth=5, min_child_weight=1, n_estimators=712, reg_alpha=1.424202471887338, reg_lambda=0.18443473677266398, subsample=0.8438257335919588; total time= 1.3min
# [CV] END colsample_bytree=0.8010716092915446, gamma=0.25739375624994676, learning_rate=0.09359393927098342, max_depth=3, min_child_weight=1, n_estimators=502, reg_alpha=3.403527257773834, reg_lambda=2.6546729165856817, subsample=0.7791132658292367; total time= 1.0min
# [CV] END colsample_bytree=0.8010716092915446, gamma=0.25739375624994676, learning_rate=0.09359393927098342, max_depth=3, min_child_weight=1, n_estimators=502, reg_alpha=3.403527257773834, reg_lambda=2.6546729165856817, subsample=0.7791132658292367; total time= 1.0min
# [CV] END colsample_bytree=0.8010716092915446, gamma=0.25739375624994676, learning_rate=0.09359393927098342, max_depth=3, min_child_weight=1, n_estimators=502, reg_alpha=3.403527257773834, reg_lambda=2.6546729165856817, subsample=0.7791132658292367; total time= 1.0min
# [CV] END colsample_bytree=0.8010716092915446, gamma=0.25739375624994676, learning_rate=0.09359393927098342, max_depth=3, min_child_weight=1, n_estimators=502, reg_alpha=3.403527257773834, reg_lambda=2.6546729165856817, subsample=0.7791132658292367; total time= 1.0min
# [CV] END colsample_bytree=0.8010716092915446, gamma=0.25739375624994676, learning_rate=0.09359393927098342, max_depth=3, min_child_weight=1, n_estimators=502, reg_alpha=3.403527257773834, reg_lambda=2.6546729165856817, subsample=0.7791132658292367; total time= 1.0min
# [CV] END colsample_bytree=0.8211572356285312, gamma=2.9634836193969676, learning_rate=0.03425599789981457, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=3.641081743059298, reg_lambda=1.838915663596266, subsample=0.8529223322374317; total time= 1.2min
# [CV] END colsample_bytree=0.8211572356285312, gamma=2.9634836193969676, learning_rate=0.03425599789981457, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=3.641081743059298, reg_lambda=1.838915663596266, subsample=0.8529223322374317; total time= 1.2min
# [CV] END colsample_bytree=0.8211572356285312, gamma=2.9634836193969676, learning_rate=0.03425599789981457, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=3.641081743059298, reg_lambda=1.838915663596266, subsample=0.8529223322374317; total time= 1.2min
# [CV] END colsample_bytree=0.8211572356285312, gamma=2.9634836193969676, learning_rate=0.03425599789981457, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=3.641081743059298, reg_lambda=1.838915663596266, subsample=0.8529223322374317; total time= 1.2min
# [CV] END colsample_bytree=0.8211572356285312, gamma=2.9634836193969676, learning_rate=0.03425599789981457, max_depth=10, min_child_weight=3, n_estimators=500, reg_alpha=3.641081743059298, reg_lambda=1.838915663596266, subsample=0.8529223322374317; total time= 1.2min
# [CV] END colsample_bytree=0.8534118843043579, gamma=2.6788734203737925, learning_rate=0.03708693101632249, max_depth=3, min_child_weight=1, n_estimators=223, reg_alpha=2.5409938837035932, reg_lambda=3.479064033954409, subsample=0.943343521925488; total time=  33.7s
# [CV] END colsample_bytree=0.8534118843043579, gamma=2.6788734203737925, learning_rate=0.03708693101632249, max_depth=3, min_child_weight=1, n_estimators=223, reg_alpha=2.5409938837035932, reg_lambda=3.479064033954409, subsample=0.943343521925488; total time=  31.7s
# [CV] END colsample_bytree=0.8534118843043579, gamma=2.6788734203737925, learning_rate=0.03708693101632249, max_depth=3, min_child_weight=1, n_estimators=223, reg_alpha=2.5409938837035932, reg_lambda=3.479064033954409, subsample=0.943343521925488; total time=  33.4s
# [CV] END colsample_bytree=0.8534118843043579, gamma=2.6788734203737925, learning_rate=0.03708693101632249, max_depth=3, min_child_weight=1, n_estimators=223, reg_alpha=2.5409938837035932, reg_lambda=3.479064033954409, subsample=0.943343521925488; total time=  32.1s
# [CV] END colsample_bytree=0.8534118843043579, gamma=2.6788734203737925, learning_rate=0.03708693101632249, max_depth=3, min_child_weight=1, n_estimators=223, reg_alpha=2.5409938837035932, reg_lambda=3.479064033954409, subsample=0.943343521925488; total time=  33.2s
# [CV] END colsample_bytree=0.730383562080754, gamma=1.1012052378277415, learning_rate=0.22334485973140536, max_depth=5, min_child_weight=4, n_estimators=963, reg_alpha=0.4808827554571038, reg_lambda=4.70261632244802, subsample=0.759028808435009; total time= 2.0min
# [CV] END colsample_bytree=0.730383562080754, gamma=1.1012052378277415, learning_rate=0.22334485973140536, max_depth=5, min_child_weight=4, n_estimators=963, reg_alpha=0.4808827554571038, reg_lambda=4.70261632244802, subsample=0.759028808435009; total time= 2.0min
# [CV] END colsample_bytree=0.730383562080754, gamma=1.1012052378277415, learning_rate=0.22334485973140536, max_depth=5, min_child_weight=4, n_estimators=963, reg_alpha=0.4808827554571038, reg_lambda=4.70261632244802, subsample=0.759028808435009; total time= 2.0min
# [CV] END colsample_bytree=0.730383562080754, gamma=1.1012052378277415, learning_rate=0.22334485973140536, max_depth=5, min_child_weight=4, n_estimators=963, reg_alpha=0.4808827554571038, reg_lambda=4.70261632244802, subsample=0.759028808435009; total time= 2.0min
# [CV] END colsample_bytree=0.730383562080754, gamma=1.1012052378277415, learning_rate=0.22334485973140536, max_depth=5, min_child_weight=4, n_estimators=963, reg_alpha=0.4808827554571038, reg_lambda=4.70261632244802, subsample=0.759028808435009; total time= 2.0min
# [CV] END colsample_bytree=0.8071005402109921, gamma=4.18855052953664, learning_rate=0.2127070351117842, max_depth=11, min_child_weight=1, n_estimators=250, reg_alpha=2.707239869137829, reg_lambda=3.478921996725411, subsample=0.6914200087189198; total time=  32.5s
# [CV] END colsample_bytree=0.8071005402109921, gamma=4.18855052953664, learning_rate=0.2127070351117842, max_depth=11, min_child_weight=1, n_estimators=250, reg_alpha=2.707239869137829, reg_lambda=3.478921996725411, subsample=0.6914200087189198; total time=  33.8s
# [CV] END colsample_bytree=0.8071005402109921, gamma=4.18855052953664, learning_rate=0.2127070351117842, max_depth=11, min_child_weight=1, n_estimators=250, reg_alpha=2.707239869137829, reg_lambda=3.478921996725411, subsample=0.6914200087189198; total time=  32.1s
# [CV] END colsample_bytree=0.8071005402109921, gamma=4.18855052953664, learning_rate=0.2127070351117842, max_depth=11, min_child_weight=1, n_estimators=250, reg_alpha=2.707239869137829, reg_lambda=3.478921996725411, subsample=0.6914200087189198; total time=  34.0s
# [CV] END colsample_bytree=0.8071005402109921, gamma=4.18855052953664, learning_rate=0.2127070351117842, max_depth=11, min_child_weight=1, n_estimators=250, reg_alpha=2.707239869137829, reg_lambda=3.478921996725411, subsample=0.6914200087189198; total time=  32.6s
# [CV] END colsample_bytree=0.6699819708383744, gamma=4.910841716647178, learning_rate=0.16499076738130428, max_depth=3, min_child_weight=2, n_estimators=996, reg_alpha=0.46551383902949606, reg_lambda=4.486078789766633, subsample=0.9601672228653322; total time= 1.6min
# [CV] END colsample_bytree=0.6699819708383744, gamma=4.910841716647178, learning_rate=0.16499076738130428, max_depth=3, min_child_weight=2, n_estimators=996, reg_alpha=0.46551383902949606, reg_lambda=4.486078789766633, subsample=0.9601672228653322; total time= 1.6min
# [CV] END colsample_bytree=0.6699819708383744, gamma=4.910841716647178, learning_rate=0.16499076738130428, max_depth=3, min_child_weight=2, n_estimators=996, reg_alpha=0.46551383902949606, reg_lambda=4.486078789766633, subsample=0.9601672228653322; total time= 1.6min
# [CV] END colsample_bytree=0.6699819708383744, gamma=4.910841716647178, learning_rate=0.16499076738130428, max_depth=3, min_child_weight=2, n_estimators=996, reg_alpha=0.46551383902949606, reg_lambda=4.486078789766633, subsample=0.9601672228653322; total time= 1.6min
# [CV] END colsample_bytree=0.6699819708383744, gamma=4.910841716647178, learning_rate=0.16499076738130428, max_depth=3, min_child_weight=2, n_estimators=996, reg_alpha=0.46551383902949606, reg_lambda=4.486078789766633, subsample=0.9601672228653322; total time= 1.6min
# [CV] END colsample_bytree=0.8532405829093072, gamma=1.6951489552435035, learning_rate=0.11476287238379826, max_depth=5, min_child_weight=4, n_estimators=251, reg_alpha=2.0225406356109503, reg_lambda=4.438850493804799, subsample=0.9403713795070051; total time=  36.9s
# [CV] END colsample_bytree=0.8532405829093072, gamma=1.6951489552435035, learning_rate=0.11476287238379826, max_depth=5, min_child_weight=4, n_estimators=251, reg_alpha=2.0225406356109503, reg_lambda=4.438850493804799, subsample=0.9403713795070051; total time=  36.9s
# [CV] END colsample_bytree=0.8532405829093072, gamma=1.6951489552435035, learning_rate=0.11476287238379826, max_depth=5, min_child_weight=4, n_estimators=251, reg_alpha=2.0225406356109503, reg_lambda=4.438850493804799, subsample=0.9403713795070051; total time=  35.8s
# [CV] END colsample_bytree=0.8532405829093072, gamma=1.6951489552435035, learning_rate=0.11476287238379826, max_depth=5, min_child_weight=4, n_estimators=251, reg_alpha=2.0225406356109503, reg_lambda=4.438850493804799, subsample=0.9403713795070051; total time=  36.8s
# [CV] END colsample_bytree=0.8532405829093072, gamma=1.6951489552435035, learning_rate=0.11476287238379826, max_depth=5, min_child_weight=4, n_estimators=251, reg_alpha=2.0225406356109503, reg_lambda=4.438850493804799, subsample=0.9403713795070051; total time=  36.6s
# [CV] END colsample_bytree=0.9742539976883791, gamma=3.926703255569718, learning_rate=0.21069647641426859, max_depth=5, min_child_weight=8, n_estimators=609, reg_alpha=4.700667212288892, reg_lambda=4.8683191837765865, subsample=0.7135683898949863; total time= 1.1min
# [CV] END colsample_bytree=0.9742539976883791, gamma=3.926703255569718, learning_rate=0.21069647641426859, max_depth=5, min_child_weight=8, n_estimators=609, reg_alpha=4.700667212288892, reg_lambda=4.8683191837765865, subsample=0.7135683898949863; total time= 1.1min
# [CV] END colsample_bytree=0.9742539976883791, gamma=3.926703255569718, learning_rate=0.21069647641426859, max_depth=5, min_child_weight=8, n_estimators=609, reg_alpha=4.700667212288892, reg_lambda=4.8683191837765865, subsample=0.7135683898949863; total time= 1.1min
# [CV] END colsample_bytree=0.9742539976883791, gamma=3.926703255569718, learning_rate=0.21069647641426859, max_depth=5, min_child_weight=8, n_estimators=609, reg_alpha=4.700667212288892, reg_lambda=4.8683191837765865, subsample=0.7135683898949863; total time= 1.0min
# [CV] END colsample_bytree=0.9742539976883791, gamma=3.926703255569718, learning_rate=0.21069647641426859, max_depth=5, min_child_weight=8, n_estimators=609, reg_alpha=4.700667212288892, reg_lambda=4.8683191837765865, subsample=0.7135683898949863; total time= 1.1min
# [CV] END colsample_bytree=0.7221455441377573, gamma=2.428068767931133, learning_rate=0.1445272428958742, max_depth=11, min_child_weight=4, n_estimators=260, reg_alpha=0.09037681807760434, reg_lambda=2.469468575917173, subsample=0.6715290836885315; total time=  42.5s
# [CV] END colsample_bytree=0.7221455441377573, gamma=2.428068767931133, learning_rate=0.1445272428958742, max_depth=11, min_child_weight=4, n_estimators=260, reg_alpha=0.09037681807760434, reg_lambda=2.469468575917173, subsample=0.6715290836885315; total time=  43.5s
# [CV] END colsample_bytree=0.7221455441377573, gamma=2.428068767931133, learning_rate=0.1445272428958742, max_depth=11, min_child_weight=4, n_estimators=260, reg_alpha=0.09037681807760434, reg_lambda=2.469468575917173, subsample=0.6715290836885315; total time=  42.7s
# [CV] END colsample_bytree=0.7221455441377573, gamma=2.428068767931133, learning_rate=0.1445272428958742, max_depth=11, min_child_weight=4, n_estimators=260, reg_alpha=0.09037681807760434, reg_lambda=2.469468575917173, subsample=0.6715290836885315; total time=  42.5s
# [CV] END colsample_bytree=0.7221455441377573, gamma=2.428068767931133, learning_rate=0.1445272428958742, max_depth=11, min_child_weight=4, n_estimators=260, reg_alpha=0.09037681807760434, reg_lambda=2.469468575917173, subsample=0.6715290836885315; total time=  42.4s
# [CV] END colsample_bytree=0.7465875138331439, gamma=3.720852615282811, learning_rate=0.22628197727563878, max_depth=3, min_child_weight=8, n_estimators=559, reg_alpha=2.5440703841938, reg_lambda=3.1816630909294767, subsample=0.7001847274422337; total time= 1.0min
# [CV] END colsample_bytree=0.7465875138331439, gamma=3.720852615282811, learning_rate=0.22628197727563878, max_depth=3, min_child_weight=8, n_estimators=559, reg_alpha=2.5440703841938, reg_lambda=3.1816630909294767, subsample=0.7001847274422337; total time= 1.0min
# [CV] END colsample_bytree=0.7465875138331439, gamma=3.720852615282811, learning_rate=0.22628197727563878, max_depth=3, min_child_weight=8, n_estimators=559, reg_alpha=2.5440703841938, reg_lambda=3.1816630909294767, subsample=0.7001847274422337; total time=  59.0s
# [CV] END colsample_bytree=0.7465875138331439, gamma=3.720852615282811, learning_rate=0.22628197727563878, max_depth=3, min_child_weight=8, n_estimators=559, reg_alpha=2.5440703841938, reg_lambda=3.1816630909294767, subsample=0.7001847274422337; total time= 1.0min
# [CV] END colsample_bytree=0.7465875138331439, gamma=3.720852615282811, learning_rate=0.22628197727563878, max_depth=3, min_child_weight=8, n_estimators=559, reg_alpha=2.5440703841938, reg_lambda=3.1816630909294767, subsample=0.7001847274422337; total time=  58.9s
# [CV] END colsample_bytree=0.8359483390242175, gamma=4.894464291375045, learning_rate=0.15602264588783654, max_depth=10, min_child_weight=3, n_estimators=126, reg_alpha=3.974056517708242, reg_lambda=2.5131854655259604, subsample=0.8307615538505436; total time=  22.3s
# [CV] END colsample_bytree=0.8359483390242175, gamma=4.894464291375045, learning_rate=0.15602264588783654, max_depth=10, min_child_weight=3, n_estimators=126, reg_alpha=3.974056517708242, reg_lambda=2.5131854655259604, subsample=0.8307615538505436; total time=  23.0s
# [CV] END colsample_bytree=0.8359483390242175, gamma=4.894464291375045, learning_rate=0.15602264588783654, max_depth=10, min_child_weight=3, n_estimators=126, reg_alpha=3.974056517708242, reg_lambda=2.5131854655259604, subsample=0.8307615538505436; total time=  21.3s
# [CV] END colsample_bytree=0.8359483390242175, gamma=4.894464291375045, learning_rate=0.15602264588783654, max_depth=10, min_child_weight=3, n_estimators=126, reg_alpha=3.974056517708242, reg_lambda=2.5131854655259604, subsample=0.8307615538505436; total time=  22.2s
# [CV] END colsample_bytree=0.8359483390242175, gamma=4.894464291375045, learning_rate=0.15602264588783654, max_depth=10, min_child_weight=3, n_estimators=126, reg_alpha=3.974056517708242, reg_lambda=2.5131854655259604, subsample=0.8307615538505436; total time=  22.2s
# RandomizedSearchCV(cv=5,
#                    estimator=XGBClassifier(base_score=None, booster=None,
#                                            callbacks=None,
#                                            colsample_bylevel=None,
#                                            colsample_bynode=None,
#                                            colsample_bytree=None, device=None,
#                                            early_stopping_rounds=None,
#                                            enable_categorical=False,
#                                            eval_metric=None, feature_types=None,
#                                            feature_weights=None, gamma=None,
#                                            grow_policy=None,
#                                            importance_type=None,
#                                            interaction_constrain...
#                                         'n_estimators': <scipy.stats._distn_infrastructure.rv_discrete_frozen object at 0x7d52901eb6e0>,
#                                         'reg_alpha': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7d528c9e3ec0>,
#                                         'reg_lambda': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7d528c9eacc0>,
#                                         'subsample': <scipy.stats._distn_infrastructure.rv_continuous_frozen object at 0x7d528c9e3980>},
#                    random_state=42, scoring='accuracy', verbose=2)

# %%
print("Best Parameters:")
print(random_search.best_params_)

print("\nBest CV Score:")
print(random_search.best_score_)
# Out:
# Best Parameters:
# {'colsample_bytree': np.float64(0.6943939678995823), 'gamma': np.float64(1.2803416138066197), 'learning_rate': np.float64(0.022130076861529402), 'max_depth': 12, 'min_child_weight': 2, 'n_estimators': 991, 'reg_alpha': np.float64(0.5394571349665223), 'reg_lambda': np.float64(0.15714592843367126), 'subsample': np.float64(0.8545641645055122)}
#
# Best CV Score:
# 0.791375

# %%
best_xgb = random_search.best_estimator_

y_pred = best_xgb.predict(X_test)

# %%
import joblib
joblib.dump(best_xgb, "xgboost_classifier.pkl")
joblib.dump(cv, "vectorizer.pkl")
# Out:
# ['vectorizer.pkl']

# %% [markdown]
# **preprocessing and vectorizer functions**

# %%
def test_common_words(q1,q2):
    w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))
    return len(w1 & w2)

# %%
def test_total_words(q1,q2):
    w1 = set(map(lambda word: word.lower().strip(), q1.split(" ")))
    w2 = set(map(lambda word: word.lower().strip(), q2.split(" ")))
    return (len(w1) + len(w2))

# %%
def test_fetch_token_features(q1,q2):

    SAFE_DIV = 0.0001

    STOP_WORDS = stopwords.words("english")

    token_features = [0.0]*8

    # Converting the Sentence into Tokens:
    q1_tokens = q1.split()
    q2_tokens = q2.split()

    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return token_features

    # Get the non-stopwords in Questions
    q1_words = set([word for word in q1_tokens if word not in STOP_WORDS])
    q2_words = set([word for word in q2_tokens if word not in STOP_WORDS])

    #Get the stopwords in Questions
    q1_stops = set([word for word in q1_tokens if word in STOP_WORDS])
    q2_stops = set([word for word in q2_tokens if word in STOP_WORDS])

    # Get the common non-stopwords from Question pair
    common_word_count = len(q1_words.intersection(q2_words))

    # Get the common stopwords from Question pair
    common_stop_count = len(q1_stops.intersection(q2_stops))

    # Get the common Tokens from Question pair
    common_token_count = len(set(q1_tokens).intersection(set(q2_tokens)))


    token_features[0] = common_word_count / (min(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[1] = common_word_count / (max(len(q1_words), len(q2_words)) + SAFE_DIV)
    token_features[2] = common_stop_count / (min(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[3] = common_stop_count / (max(len(q1_stops), len(q2_stops)) + SAFE_DIV)
    token_features[4] = common_token_count / (min(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)
    token_features[5] = common_token_count / (max(len(q1_tokens), len(q2_tokens)) + SAFE_DIV)

    # Last word of both question is same or not
    token_features[6] = int(q1_tokens[-1] == q2_tokens[-1])

    # First word of both question is same or not
    token_features[7] = int(q1_tokens[0] == q2_tokens[0])

    return token_features

# %%
def test_fetch_length_features(q1,q2):

    length_features = [0.0]*3

    # Converting the Sentence into Tokens:
    q1_tokens = q1.split()
    q2_tokens = q2.split()

    if len(q1_tokens) == 0 or len(q2_tokens) == 0:
        return length_features

    # Absolute length features
    length_features[0] = abs(len(q1_tokens) - len(q2_tokens))

    #Average Token Length of both Questions
    length_features[1] = (len(q1_tokens) + len(q2_tokens))/2

    strs = list(distance.lcsubstrings(q1, q2))
    length_features[2] = len(strs[0]) / (min(len(q1), len(q2)) + 1)

    return length_features

# %%
def test_fetch_fuzzy_features(q1,q2):

    fuzzy_features = [0.0]*4

    # fuzz_ratio
    fuzzy_features[0] = fuzz.QRatio(q1, q2)

    # fuzz_partial_ratio
    fuzzy_features[1] = fuzz.partial_ratio(q1, q2)

    # token_sort_ratio
    fuzzy_features[2] = fuzz.token_sort_ratio(q1, q2)

    # token_set_ratio
    fuzzy_features[3] = fuzz.token_set_ratio(q1, q2)

    return fuzzy_features

# %%
def query_point_creator(q1,q2):

    input_query = []

    # preprocess
    q1 = preprocess(q1)
    q2 = preprocess(q2)

    # fetch basic features
    # Removed len(q1) and len(q2) as these were not part of the training features
    input_query.append(len(q1.split(" ")))
    input_query.append(len(q2.split(" ")))

    input_query.append(test_common_words(q1,q2))
    input_query.append(test_total_words(q1,q2))
    input_query.append(round(test_common_words(q1,q2)/test_total_words(q1,q2),2))

    # fetch token features
    token_features = test_fetch_token_features(q1,q2)
    input_query.extend(token_features)

    # fetch length based features
    length_features = test_fetch_length_features(q1,q2)
    input_query.extend(length_features)

    # fetch fuzzy features
    fuzzy_features = test_fetch_fuzzy_features(q1,q2)
    input_query.extend(fuzzy_features)

    # bow feature for q1
    q1_bow = cv.transform([q1]).toarray()

    # bow feature for q2
    q2_bow = cv.transform([q2]).toarray()



    return np.hstack((np.array(input_query).reshape(1,20),q1_bow,q2_bow))

# %%
q1 = 'Where is the capital of India?'
q2 = 'What is the current capital of Pakistan?'
q3 = 'What is the capital of India?'
q4 = 'What is the business capital of India?'

# %%
best_xgb.predict(query_point_creator(q1,q4))
# Out:
# array([0])
